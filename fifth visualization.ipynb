# %%
import pandas as pd

# %%
#Note: The Data belongs to the year 2015 ,No such data is available for the years after 2015 
df=pd.read_csv("Gun ownership by 2015.csv")

# %%
len(df)
# Out:
# 51

# %%
#df

# %%
df2=pd.read_csv("2015.csv")

# %%
#df2

# %%
df3=df.merge(df2)

# %%
df3
# Out:
#                 Location  Gun Ownership(percentage)  \
# 0                Alabama                       48.9
# 1                 Alaska                       61.7
# 2                Arizona                       32.3
# 3               Arkansas                       57.9
# 4             California                       19.8
# 5               Colorado                       34.3
# 6            Connecticut                       16.6
# 7               Delaware                        5.2
# 8   District of Columbia                       25.9
# 9                Florida                       32.5
# 10               Georgia                       31.6
# 11                Hawaii                       45.1
# 12                 Idaho                       56.9
# 13              Illinois                       26.2
# 14               Indiana                       33.8
# 15                  Iowa                       33.8
# 16                Kansas                       32.2
# 17              Kentucky                       42.4
# 18             Louisiana                       44.5
# 19                 Maine                       22.6
# 20              Maryland                       20.7
# 21         Massachusetts                       22.6
# 22              Michigan                       28.8
# 23             Minnesota                       36.7
# 24           Mississippi                       42.8
# 25              Missouri                       27.1
# 26               Montana                       52.3
# 27              Nebraska                       19.8
# 28                Nevada                       37.5
# 29         New Hampshire                       14.4
# 30            New Jersey                       11.3
# 31              New York                       10.3
# 32            New Mexico                       49.9
# 33        North Carolina                       28.7
# 34          North Dakota                       47.9
# 35                  Ohio                       19.6
# 36              Oklahoma                       31.2
# 37                Oregon                       26.6
# 38          Pennsylvania                       27.1
# 39          Rhode Island                        5.8
# 40        South Carolina                       44.4
# 41          South Dakota                       35.0
# 42             Tennessee                       39.4
# 43                 Texas                       35.7
# 44                  Utah                       31.9
# 45               Vermont                       28.8
# 46              Virginia                       29.3
# 47            Washington                       27.7
# 48         West Virginia                       54.2
# 49             Wisconsin                       34.7
# 50               Wyoming                       53.8
#
#     Firearms Death Rate per 100,000
# 0                              19.7
# 1                              23.4
# 2                              13.8
# 3                              17.0
# 4                               7.7
# 5                              12.6
# 6                               5.3
# 7                              12.1
# 8                              15.3
# 9                              12.0
# 10                             14.1
# 11                              3.6
# 12                             14.9
# 13                              9.5
# 14                             12.7
# 15                              7.8
# 16                             11.4
# 17                             15.2
# 18                             20.5
# 19                              9.8
# 20                             11.9
# 21                              3.0
# 22                             11.7
# 23                              7.4
# 24                             19.7
# 25                             18.2
# 26                             19.4
# 27                              8.9
# 28                             15.0
# 29                              8.9
# 30                              5.4
# 31                              4.2
# 32                             18.6
# 33                             12.6
# 34                             12.8
# 35                             11.9
# 36                             18.0
# 37                             11.4
# 38                             11.4
# 39                              4.7
# 40                             17.3
# 41                             11.1
# 42                             15.9
# 43                             11.8
# 44                             12.9
# 45                              9.6
# 46                             10.9
# 47                              9.8
# 48                             14.1
# 49                             10.4
# 50                             19.8

# %%
df3.to_csv("Fifth.csv")
